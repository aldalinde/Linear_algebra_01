# %% [markdown]
# # Урок 2

# %% [markdown]
# # Линейное пространство. Основные понятия. Часть 2

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>

# %% [markdown]
# (x, y) = 0 - 21 + 54 = 33

# %% [markdown]
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %% [markdown]
# (x, y) = - 21 - 4 + 2 = - 23

# %% [markdown]
# __2.__ Найти нормы векторов $a=(4, 2, 4)$ и $b=(12, 3, 4)$ и угол между ними.

# %% [markdown]
# $$l_1(a) = 4 + 2 + 4 = 10$$
# $$l_2(a) = \sqrt{16 + 4 + 16} = \sqrt{36} = 6 $$
# $$l_1(b) = 12+3+4 = 19$$
# $$l_2(b) = \sqrt {144 + 9 + 16} = 13 $$

# %% [markdown]
# $$ cos \alpha = \frac{48 +6+16}{6*13}= \frac{70}{78} \approx 0,897 $$

# %% [markdown]
# $$ cos \alpha \approx 26^\circ $$

# %% [markdown]
# __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
#
# - в этом случае скалярное произведение является вещественным числом, что говорит о соблюдении общего правила для евклидова пространства, согласно которому каждой упорядоченной паре векторов  𝑥  и  𝑦  поставлено в соответствие вещественное число, называемое скалярным произведением.
#
# При этом указанное правило должно подчиняться четырем аксиомам:<br>
# 1) $(x,y)=(y,x);$ - думаю, вытекает из условия о равенстве скалярного произведения произведению длин векторов<br>
# 2) $(\lambda x, y)=\lambda(x, y);$<br>
# 3) $(x_{1}+x_{2},y)=(x_{1},y)+(x_{2},y);$<br>
# - раз пространство линейное, значит для него установлено соблюдение правил: <br>
# 2) ассоциативность операции умножения вектора на скаляр: $\lambda (\mu \cdot u)=(\lambda \cdot \mu) u$;<br>
# 3) дистрибутивность относительно сложения векторов: $\lambda(u+v)=\lambda u+\lambda v$;<br>
#
#
# 4) $(x, x)\geq0$, причем $(x,x)=0\Leftrightarrow x=0.$ раз скалярное произведение векторов равно произведению их длин, значит скалярное произведение вектора с самим собой будет равно квадрату его длины $(x, x) = \left\|x\right\|^2 $ => будет больше или равно 0 и $\left\|x\right\|^2 = 0 \Leftrightarrow x = 0 $;<br>
# \- при этом условии вектора однонаправлены

# %% [markdown]
# б) утроенное обычное скалярное произведение векторов?
# - пока не поняла, что это значит. Что такое "обычное"?  Буду думать<br>
# (x,y) = $3(a_{1}b_{1}+a_{2}b_{2}+...+a_{n}b_{n}.)$? => = (3x, y)?,<br>
# \- кажется не противоречит подчинению аксиом...

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ - дано два, а должно быть три вектора, чтобы образовать базис для $\mathbb{R}^{3}$<br>

# %% [markdown]
# б) $a = (1/\sqrt{2},-1/\sqrt{2},0),b = (1/\sqrt{2},1/\sqrt{2},0), c = (0,0,1);$<br>
# - (a,b) = 0, (a,c) = (b,c) = 0 вектора ортогональны
# - (a,a) = 1 = (b,b) = (c, c) вектора единичные
# ___________________________________________________
# вектора образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$

# %% [markdown]
# в) $d = (1/2, -1/2, 0), e = (0, 1/2, 1/2), f = (0,0,1);$<br>
# - $ (d,d) \neq 1$ , $(e,e) \neq 1$ вектора d и e не единичные
# - $ (d,e) \neq 0 $ , $ (f,e) \neq 0 $  вектора не ортогональные

# %% [markdown]
# г) $(1,0,0),(0,1,0),(0,0,1)?$ - стандартный базис является ортнормированным
